# %%
# Step1: Import libraries

import numpy as np 
import pandas as pd #for dataframe
import seaborn as sns #for loading data
import matplotlib.pyplot as plt
import scipy.stats as st
sns.set(color_codes=True)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.metrics import accuracy_score,classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline #machine learning library provides tools for various tasks such as classification,regression,clustering
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error # to find the error

# %%
#step2: Read the DataSet

df=pd.read_csv('last-data.csv')
df
# Out:
#      Unnamed: 0                Area Relationship status  Age  Gender  \
# 0             1  Out side kurdistan             Married   27    male
# 1             2           Kurdistan             Married   20  Female
# 2             3           Kurdistan             Married   21  Female
# 3             4  Out side kurdistan             Married   26  Female
# 4             5           Kurdistan             Married   21  Female
# ..          ...                 ...                 ...  ...     ...
# 550         551           Kurdistan             Married   42    Male
# 551         552  Out side kurdistan             Married   33  Female
# 552         553  Out side kurdistan             Married   32    Male
# 553         554           kurdistan              Single   23    Male
# 554         555  Out side kurdistan              Single   32    Male
#
#     Year of leave Place of leave Factor of leave  Distance(km) from kurdistan
# ...

# %%
# show the Column of dataset
colums =df.columns
colums
# Out:
# Index(['Unnamed: 0', 'Area', 'Relationship status', 'Age', 'Gender',
#        'Year of leave', 'Place of leave', 'Factor of leave',
#        'Distance(km) from kurdistan'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Unnamed: 0                Area Relationship status  Age  Gender  \
# 0           1  Out side kurdistan             Married   27    male
# 1           2           Kurdistan             Married   20  Female
# 2           3           Kurdistan             Married   21  Female
# 3           4  Out side kurdistan             Married   26  Female
# 4           5           Kurdistan             Married   21  Female
# 5           6           Kurdistan             Married   22  Female
# 6           7           Kurdistan             Married   22  Female
# 7           8           Kurdistan             Married   23  Female
# 8           9           Kurdistan             Married   23  Female
# 9          10           Kurdistan             Married   24  Female
#
#   Year of leave Place of leave Factor of leave  Distance(km) from kurdistan
# 0          2013      baritania       bussiness                        484.1
# 1       Unleave        Unleave         Unleave                          0.0
# ...

# %%
df.tail(10)
# Out:
#      Unnamed: 0                Area Relationship status  Age  Gender  \
# 545         546  Out side kurdistan              Single   42  Female
# 546         547  Out side kurdistan             Married   24    Male
# 547         548  Out side kurdistan              Single   24    Male
# 548         549  Out side kurdistan              Single   24    Male
# 549         550  Out side kurdistan             Married   42    Male
# 550         551           Kurdistan             Married   42    Male
# 551         552  Out side kurdistan             Married   33  Female
# 552         553  Out side kurdistan             Married   32    Male
# 553         554           kurdistan              Single   23    Male
# 554         555  Out side kurdistan              Single   32    Male
#
#     Year of leave Place of leave Factor of leave  Distance(km) from kurdistan
# 545          2021            USA           study                       7789.0
# ...

# %%
df.shape
# Out:
# (555, 9)

# %%
df.hist(figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'Age'}>],
#        [<AxesSubplot:title={'center':'Distance(km) from kurdistan'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
df.hist(column="Age",by="Year of leave")
# Out:
# array([[<AxesSubplot:title={'center':'1988'}>,
#         <AxesSubplot:title={'center':'1990'}>,
#         <AxesSubplot:title={'center':'1991'}>,
#         <AxesSubplot:title={'center':'1992'}>,
#         <AxesSubplot:title={'center':'1993'}>,
#         <AxesSubplot:title={'center':'1995'}>],
#        [<AxesSubplot:title={'center':'1996'}>,
#         <AxesSubplot:title={'center':'1997'}>,
#         <AxesSubplot:title={'center':'1998'}>,
#         <AxesSubplot:title={'center':'1999'}>,
#         <AxesSubplot:title={'center':'2000'}>,
#         <AxesSubplot:title={'center':'2001'}>],
#        [<AxesSubplot:title={'center':'2002'}>,
#         <AxesSubplot:title={'center':'2003'}>,
#         <AxesSubplot:title={'center':'2004'}>,
#         <AxesSubplot:title={'center':'2005'}>,
#         <AxesSubplot:title={'center':'2007'}>,
#         <AxesSubplot:title={'center':'2008'}>],
#        [<AxesSubplot:title={'center':'2010'}>,
#         <AxesSubplot:title={'center':'2011'}>,
# ...

# %%
age = df['Age']  
age
# Out:
# 0      27
# 1      20
# 2      21
# 3      26
# 4      21
#        ..
# 550    42
# 551    33
# 552    32
# 553    23
# 554    32
# Name: Age, Length: 555, dtype: int64

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\saya\anaconda3\New\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
x=st.skewnorm.rvs(10,size=500)
x[0:20]
# Out:
# array([0.84249307, 1.44347004, 0.30517852, 0.58763957, 0.37368578,
#        1.71689816, 0.98110683, 0.6588056 , 0.38271825, 1.30300687,
#        0.63869213, 1.68507791, 0.07726554, 1.69358063, 0.5006714 ,
#        0.01073021, 0.15456301, 0.41767354, 0.71398455, 0.51837529])

# %%
fig, ax = plt.subplots()
_ = plt.hist(x, color = 'black')

# %%
xbar=x.mean()
xbar
# Out:
# 0.8136625205146881

# %%
fig, ax = plt.subplots()
plt.axvline(x = x.mean(), color='orange')
_ = plt.hist(x, color = 'lightblue')

# %%
np.median(x)
# Out:
# 0.6833982602223937

# %%
fig, ax = plt.subplots()
plt.axvline(x = np.mean(x), color='orange')
plt.axvline(x = np.median(x), color='green')
_ = plt.hist(x, color = 'lightgray')

# %%
x.var()  #variance
# Out:
# 0.39117661967299816

# %%
x.var()**(1/2) #standard deviation
# Out:
# 0.6254411400547601

# %%
sigma = x.std()
sigma
# Out:
# 0.6254411400547601

# %%
fig, ax = plt.subplots()
plt.axvline(x = xbar, color='orange')
plt.axvline(x = xbar+sigma, color='olivedrab')
plt.axvline(x = xbar-sigma, color='olivedrab')
_ = plt.hist(x, color = 'lightgray')

# %%
sigma/(x.size)**(1/2) #standard error
# Out:
# 0.027970578101748203

# %%
st.sem(x)
# Out:
# 0.027998590705766144

# %%
st.sem(x, ddof=0)
# Out:
# 0.027970578101748203

# %%
_ = sns.displot(x, kde=True)

# %%
x.mean()
# Out:
# 0.8136625205146881

# %%
x.std()
# Out:
# 0.6254411400547601

# %%
x_sample = np.random.choice(x, size=15, replace=False)
x_sample
# Out:
# array([0.16247783, 1.84747046, 0.94025165, 0.25450491, 0.78831983,
#        1.06726433, 0.05763556, 0.79732458, 2.12982132, 0.07726554,
#        0.84249307, 0.48393558, 1.25370558, 0.30517852, 0.13887095])

# %%
x_sample.mean()
# Out:
# 0.7431013144062372

# %%
def sample_mean_calculator(input_dist, sample_size, n_samples):
    sample_means = []
    for i in range(n_samples):
        sample = np.random.choice(input_dist, size=sample_size, replace=False)
        sample_means.append(sample.mean())
    return sample_means

# %%
sns.displot(sample_mean_calculator(x, 20, 20), color='orange', kde=True)
_ = plt.xlim(-1.5, 1.5)

# %%
sns.displot(sample_mean_calculator(x, 10, 1000), color='green', kde=True)
_ = plt.xlim(-1.5, 1.5)

# %%
sns.displot(sample_mean_calculator(x, 100, 1000), color='blue', kde=True)
_ = plt.xlim(-1.5, 1.5)

# %%
sns.displot(sample_mean_calculator(x, 500, 100), color='red', kde=True)
_ = plt.xlim(-1.5, 1.5)

# %%
s = st.skewnorm.rvs(10, size=10000)

# %%
_ = sns.displot(s, kde=True)

# %%
s = st.skewnorm.rvs(-10, size=10000)

# %%
_ = sns.displot(s, kde=True)

# %%
_ = sns.displot(sample_mean_calculator(s, 10, 1000), color='black', kde=True)

# %%
_ = sns.displot(sample_mean_calculator(s, 1000, 1000), color='gray', kde=True)

# %%
m = np.concatenate((np.random.normal(size=5000), np.random.normal(loc = 7.0, size=5000)))

# %%
_ = sns.displot(m, kde=True)

# %%
m = np.concatenate((np.random.normal(size=5000), np.random.normal(loc = 7.0, size=5000),np.random.normal(size=5000), np.random.normal(loc = 12.0, size=5000)))

# %%
_ = sns.displot(m, kde=True)

# %%
_ = sns.displot(sample_mean_calculator(m, 1000, 1000), color='black', kde=True)

# %%
u = np.random.uniform(size=50000)

# %%
_ = sns.displot(u)

# %%
_ = sns.displot(sample_mean_calculator(u, 1000, 1000), color='green', kde=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                     0
# Area                           0
# Relationship status            0
# Age                            0
# Gender                         0
# Year of leave                  0
# Place of leave                 0
# Factor of leave                0
# Distance(km) from kurdistan    0
# dtype: int64

# %%
y=df['Age']

# %%
x=df.drop(['Age'],axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=0)

# %%
x_train.shape
# Out:
# (371, 8)

# %%
x_test.shape
# Out:
# (184, 8)

# %%
categorical_columns=[col for col in x_train.columns if x_train[col].dtype=='object']
numerical_columns=[col for col in x_train.columns if col not in categorical_columns]

# %%
numeric_transformer=StandardScaler()
categorical_transformer=OneHotEncoder(handle_unknown='ignore')

# %%
preprocessor=ColumnTransformer(transformers=[('num',numeric_transformer,numerical_columns),('cat',categorical_transformer,categorical_columns)])

# %%
#create a linear regression model
model=LinearRegression()

# %%
#create the pipeline
pipeline=Pipeline(steps=[('preprocessor',preprocessor),('model',model)])

# %%
#fit the model on the training data
pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Unnamed: 0',
#                                                    'Distance(km) from '
#                                                    'kurdistan']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Area',
#                                                    'Relationship status',
#                                                    'Gender', 'Year of leave',
#                                                    'Place of leave',
#                                                    'Factor of leave'])])),
#                 ('model', LinearRegression())])

# %%
#make predictions on the test set
y_pred=pipeline.predict(x_test)

# %%
#evaluate the model performance
mse=mean_squared_error(y_test,y_pred)
print(f'Mean Squared Error:{mse}')
# Out:
# Mean Squared Error:24.47739807424619

# %%
#check the prediction
new_data_predictions=pipeline.predict(df)
print(f'predictions for the new data:{new_data_predictions}')
# Out:
# predictions for the new data:[26.99829452 32.04182367 32.00925263 26.00039686 31.94411054 31.9115395
#  31.87896845 31.84639741 31.81382636 31.78125532 31.74868428 31.71611323
#  31.68354219 31.65097114 31.6184001  31.58582906 31.55325801 31.52068697
#  31.48811592 31.45554488 31.42297383 31.39040279 31.35783175 31.3252607
#  31.29268966 31.26011861 31.22754757 31.19497653 31.16240548 31.12983444
#  31.09726339 31.06469235 31.03212131 30.99955026 30.96697922 30.93440817
#  28.84865448 28.81608343 28.78351239 28.75094135 28.7183703  28.68579926
#  28.65322821 28.62065717 28.58808613 28.55551508 28.52294404 28.49037299
#  28.45780195 28.42523091 28.39265986 28.36008882 28.32751777 28.29494673
#  28.26237568 28.22980464 28.1972336  28.16466255 28.13209151 28.09952046
#  28.06694942 28.03437838 28.00180733 27.96923629 27.93666524 27.9040942
#  27.87152316 27.83895211 27.80638107 27.77381002 27.74123898 27.70866794
# ...

# %%
#plot the prediction
plt.plot(new_data_predictions)
plt.show()
